# %%
import pandas as pd
import numpy as np
import yfinance as yf

import os
os.chdir('..')

from utils.download_ticker import download

# %%
df = download('AAPL', '2014-09-30', '2024-09-30')
# Out:
# [*********************100%***********************]  1 of 1 completed
